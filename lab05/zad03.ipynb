# %%
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.tree import DecisionTreeClassifier
from sklearn import tree
from sklearn import metrics
import matplotlib.pyplot as plt

irys = pd.read_csv("iris.csv")

all_inputs = irys[['sepal.length','sepal.width','petal.length','petal.width']].values
all_classes = irys['species'].values

(train_inputs, test_inputs, train_classes, test_classes) = train_test_split(all_inputs, all_classes, train_size=0.7, random_state=278779)

# %%
dtc = DecisionTreeClassifier()

dtc.fit(train_inputs, train_classes)

result = round(dtc.score(test_inputs, test_classes)*10000)/100
print(str(result) + "%")

result = round(dtc.score(train_inputs, train_classes)*10000)/100
print(str(result) + "%")
# Out:
# 88.89%
# 100.0%

# %%
tree.plot_tree(dtc)
# Out:
# [Text(0.3333333333333333, 0.9166666666666666, 'x[3] <= 0.8\ngini = 0.664\nsamples = 105\nvalue = [39, 33, 33]'),
#  Text(0.16666666666666666, 0.75, 'gini = 0.0\nsamples = 39\nvalue = [39, 0, 0]'),
#  Text(0.5, 0.75, 'x[2] <= 4.85\ngini = 0.5\nsamples = 66\nvalue = [0, 33, 33]'),
#  Text(0.3333333333333333, 0.5833333333333334, 'gini = 0.0\nsamples = 31\nvalue = [0, 31, 0]'),
#  Text(0.6666666666666666, 0.5833333333333334, 'x[3] <= 1.75\ngini = 0.108\nsamples = 35\nvalue = [0, 2, 33]'),
#  Text(0.5, 0.4166666666666667, 'x[3] <= 1.55\ngini = 0.444\nsamples = 6\nvalue = [0, 2, 4]'),
#  Text(0.3333333333333333, 0.25, 'gini = 0.0\nsamples = 3\nvalue = [0, 0, 3]'),
#  Text(0.6666666666666666, 0.25, 'x[0] <= 6.95\ngini = 0.444\nsamples = 3\nvalue = [0, 2, 1]'),
#  Text(0.5, 0.08333333333333333, 'gini = 0.0\nsamples = 2\nvalue = [0, 2, 0]'),
#  Text(0.8333333333333334, 0.08333333333333333, 'gini = 0.0\nsamples = 1\nvalue = [0, 0, 1]'),
# ...

# %%
dtc.fit(train_inputs, train_classes)
y_pred = dtc.predict(test_inputs)

cm = metrics.confusion_matrix(test_classes,y_pred,labels=dtc.classes_)
disp = metrics.ConfusionMatrixDisplay(confusion_matrix=cm,display_labels=dtc.classes_)
disp.plot()
